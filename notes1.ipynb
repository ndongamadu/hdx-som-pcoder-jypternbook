# %% [markdown]
#     Importation des modules

# %%
import pandas as pd

# %%
cash = pd.read_excel('data/som-cash.xlsx')
cash.head()
# Out:
#          Cluster   Organization Implementing partner    Programme Name  \
# 0     Protection  QATAR CHARITY                  NaN  FS & Livelihood
# 1  Food security            DRC                  NaN  FS & Livelihood
# 2  Food security            ACF                  NaN  FS & Livelihood
# 3  Food security            ACF                  NaN  FS & Livelihood
# 4  Food security            ACF                  NaN  FS & Livelihood
#
#            Activity description                                      Donor  \
# 0  Unconditional cash transfers                              Qatar Charity
# 1            CFW Rehabilitation  Office of U.S Foreign Disaster Assistance
# 2  Unconditional cash transfers                                       DFID
# 3  Unconditional cash transfers                                        SHF
# 4  Unconditional cash transfers                                       DFID
#
#   Modality Conditionality Restriction\n  \
# 0     cash  Unconditional  Unrestricted
# ...

# %%
cash.to_csv('cash-csv.csv')
f = open('cash-csv.csv','r')
f.readline()[:1000].strip()
# Out:
# ',Cluster,Organization,Implementing partner,Programme Name,Activity description,Donor,Modality,Conditionality,"Restriction'

# %%
cash.head()
# Out:
#          Cluster   Organization Implementing partner    Programme Name  \
# 0     Protection  QATAR CHARITY                  NaN  FS & Livelihood
# 1  Food security            DRC                  NaN  FS & Livelihood
# 2  Food security            ACF                  NaN  FS & Livelihood
# 3  Food security            ACF                  NaN  FS & Livelihood
# 4  Food security            ACF                  NaN  FS & Livelihood
#
#            Activity description                                      Donor  \
# 0  Unconditional cash transfers                              Qatar Charity
# 1            CFW Rehabilitation  Office of U.S Foreign Disaster Assistance
# 2  Unconditional cash transfers                                       DFID
# 3  Unconditional cash transfers                                        SHF
# 4  Unconditional cash transfers                                       DFID
#
#   Modality Conditionality Restriction\n  \
# 0     cash  Unconditional  Unrestricted
# ...

# %%
cash['region_code']=0
cash[['Cluster','Organization','Region','District','region_code']]
# Out:
#             Cluster   Organization           Region      District  region_code
# 0        Protection  QATAR CHARITY            Awdal        Borama            0
# 1     Food security            DRC            Awdal       Lughaye            0
# 2     Food security            ACF           Bakool     Ceelbarde            0
# 3     Food security            ACF           Bakool         Xudur            0
# 4     Food security            ACF           Bakool         Xudur            0
# 5     Food security         OTHERS           Bakool         Xudur            0
# 6        Protection  QATAR CHARITY           Bakool         Xudur            0
# 7     Food security            ACF           Bakool    Rab Dhuure            0
# 8     Food security         OTHERS           Bakool     Tayeeglow            0
# 9     Food security            ACF           Bakool        Waajid            0
# 10    Food security         OTHERS           Bakool        Waajid            0
# ...

# %%
cash.loc[cash['Region']=='Galgaduud',['region_code']] = 19

# %%
cash['region_code']=0
cash.head()
# Out:
#          Cluster   Organization Implementing partner    Programme Name  \
# 0     Protection  QATAR CHARITY                  NaN  FS & Livelihood
# 1  Food security            DRC                  NaN  FS & Livelihood
# 2  Food security            ACF                  NaN  FS & Livelihood
# 3  Food security            ACF                  NaN  FS & Livelihood
# 4  Food security            ACF                  NaN  FS & Livelihood
#
#            Activity description                                      Donor  \
# 0  Unconditional cash transfers                              Qatar Charity
# 1            CFW Rehabilitation  Office of U.S Foreign Disaster Assistance
# 2  Unconditional cash transfers                                       DFID
# 3  Unconditional cash transfers                                        SHF
# 4  Unconditional cash transfers                                       DFID
#
#   Modality Conditionality Restriction\n  \
# 0     cash  Unconditional  Unrestricted
# ...

# %%
galga= cash.loc[cash.Region == "Galgaduud"]
galga.region_code
# Out:
# 64      19
# 65      19
# 208     19
# 506     19
# 507     19
# 508     19
# 791     19
# 792     19
# 808     19
# 809     19
# 810     19
# 811     19
# 812     19
# 976     19
# 977     19
# 978     19
# 979     19
# 980     19
# 996     19
# 997     19
# 998     19
# 999     19
# 1000    19
# 1040    19
# 1236    19
# 1237    19
# 1238    19
# 1239    19
# 1240    19
# 1241    19
#         ..
# 1409    19
# 1438    19
# 1670    19
# 1724    19
# 1805    19
# 1806    19
# 1815    19
# 1828    19
# 1846    19
# 1936    19
# 1961    19
# 1962    19
# 1963    19
# 1964    19
# 1965    19
# 1966    19
# 1967    19
# 1968    19
# 1969    19
# 1970    19
# 1971    19
# 1972    19
# 1973    19
# 1974    19
# 1975    19
# 1976    19
# 1977    19
# 1978    19
# 1979    19
# 1980    19
# Name: region_code, Length: 81, dtype: int64

# %%
cash.groupby('Region').count()
# Out:
#                  Cluster  Organization  Implementing partner  Programme Name  \
# Region
# Awdal                 47            47                    45              47
# Bakool               102           102                    88             102
# Banadir              133           133                   101              87
# Bari                 163           163                   121             159
# Bay                  324           324                   297             277
# Galgaduud             81            81                    57              53
# Gedo                 219           219                   197             172
# Hiraan               267           267                   239             249
# Lower Juba           133           133                    89             126
# Lower Shabelle       140           140                   133             110
# Middle Juba           22            22                    20              22
# ...

# %%
cash['restriction']=cash['Restriction\n']
cash.dtypes
# Out:
# Cluster                                          object
# Organization                                     object
# Implementing partner                             object
# Programme Name                                   object
# Activity description                             object
# Donor                                            object
# Modality                                         object
# Conditionality                                   object
# Restriction\n                                    object
# Transfer value\n                                 object
# Frequency \n                                     object
# Delivery mechanism                               object
# Region                                           object
# District                                         object
# Specific Location                                object
# Rural/ Urban                                     object
# Status (Completed, Ongoing, planned)             object
# ...

# %%
cash.isnull()
# Out:
#       Cluster  Organization  Implementing partner  Programme Name  \
# 0       False         False                  True           False
# 1       False         False                  True           False
# 2       False         False                  True           False
# 3       False         False                  True           False
# 4       False         False                  True           False
# 5       False         False                  True           False
# 6       False         False                  True           False
# 7       False         False                  True           False
# 8       False         False                  True           False
# 9       False         False                  True           False
# 10      False         False                  True           False
# 11      False         False                  True           False
# 12      False         False                  True           False
# ...

# %%
cash['Cluster'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2599    False
# 2600    False
# 2601    False
# 2602    False
# 2603    False
# 2604    False
# 2605    False
# 2606    False
# 2607    False
# 2608    False
# 2609    False
# 2610    False
# 2611    False
# 2612    False
# 2613    False
# 2614    False
# 2615    False
# 2616    False
# 2617    False
# 2618    False
# 2619    False
# 2620    False
# 2621    False
# 2622    False
# 2623    False
# 2624    False
# 2625    False
# 2626    False
# 2627    False
# 2628     True
# ...

# %%
cash.describe()
# Out:
#            Y_COORD       X_COORD    Households        Women          Men  \
# count  1173.000000  1.190000e+03   2270.000000  1029.000000  1026.000000
# mean      6.493826  3.711263e+03    289.213216   317.107289   291.929708
# std       6.543095  1.265828e+05    796.488057   551.899744   551.585778
# min      -1.132700  0.000000e+00      0.000000     0.000000     0.000000
# 25%       3.080860  4.353381e+01     51.250000    19.000000    22.000000
# 50%       6.145680  4.528413e+01    110.000000    81.000000    96.000000
# 75%       9.155187  4.757969e+01    200.000000   397.980000   284.580000
# max      44.868730  4.366691e+06  12000.000000  4156.560000  4879.440000
#
#              Girls         Boys  Total transferred Value (US$)  region_code
# count   273.000000   272.000000                   1.597000e+03  2629.000000
# mean    359.712088   337.408824                   2.178265e+04     0.585394
# std     620.780502   585.959168                   6.050588e+04     3.283884
# ...

# %%
cash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2629 entries, 0 to 2628
# Data columns (total 32 columns):
# Cluster                                  2628 non-null object
# Organization                             2627 non-null object
# Implementing partner                     2257 non-null object
# Programme Name                           2356 non-null object
# Activity description                     2608 non-null object
# Donor                                    2468 non-null object
# Modality                                 2626 non-null object
# Conditionality                           1704 non-null object
# Restriction
#                              1686 non-null object
# Transfer value
#                           1618 non-null object
# Frequency
#                               1712 non-null object
# Delivery mechanism                       1593 non-null object
# Region                                   2625 non-null object
# ...

# %%
cashforviz = cash[['Cluster','Organization','Conditionality','restriction','Delivery mechanism','Status (Completed, Ongoing, planned)','April Individuals','Region','District']]

# %%
cashforviz
# Out:
#             Cluster   Organization Conditionality   restriction  \
# 0        Protection  QATAR CHARITY  Unconditional  Unrestricted
# 1     Food security            DRC  Cash for Work  Unrestricted
# 2     Food security            ACF  Unconditional  Unrestricted
# 3     Food security            ACF  Unconditional  Unrestricted
# 4     Food security            ACF  Unconditional  Unrestricted
# 5     Food security         OTHERS  Unconditional  Unrestricted
# 6        Protection  QATAR CHARITY  Unconditional  Unrestricted
# 7     Food security            ACF  Unconditional  Unrestricted
# 8     Food security         OTHERS  Unconditional  Unrestricted
# 9     Food security            ACF  Unconditional  Unrestricted
# 10    Food security         OTHERS  Unconditional  Unrestricted
# 11    Food security            WVI  Cash for Work    Restricted
# 12    Food security            WVI  Unconditional  Unrestricted
# 13    Food security            ACF  Unconditional  Unrestricted
# ...

# %%
cashforviz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2629 entries, 0 to 2628
# Data columns (total 9 columns):
# Cluster                                 2628 non-null object
# Organization                            2627 non-null object
# Conditionality                          1704 non-null object
# restriction                             1686 non-null object
# Delivery mechanism                      1593 non-null object
# Status (Completed, Ongoing, planned)    2515 non-null object
# April Individuals                       2123 non-null object
# Region                                  2625 non-null object
# District                                2528 non-null object
# dtypes: object(9)
# memory usage: 184.9+ KB

# %% [markdown]
# ## to numeric cashforviz[['Refion','District']]=cashforviz[['Region','District']].apply(pd.to_numeric)

# %%
pcodes = pd.read_csv('data/somalia-adm1-adm2-codes.csv', usecols=['REG_NAME', 'REG_CODE','DIST_NAME','DIS_CODE'])
pcodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 4 columns):
# REG_NAME     74 non-null object
# REG_CODE     74 non-null int64
# DIST_NAME    74 non-null object
# DIS_CODE     74 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 2.4+ KB

# %%
pcodes.pivot_table(index=['REG_NAME','DIST_NAME'])
# Out:
#                                DIS_CODE  REG_CODE
# REG_NAME        DIST_NAME
# Awdal           Baki               1102        11
#                 Borama             1101        11
#                 Lughaye            1103        11
#                 Zeylac             1104        11
# Bakool          Ceel Barde         2502        25
#                 Rab Dhuure         2505        25
#                 Tayeeglow          2503        25
#                 Waajid             2504        25
#                 Xudur              2501        25
# Banadir         Banadir              22        22
# Bari            Bandarbeyla        1602        16
#                 Bossaso            1601        16
#                 Caluula            1603        16
#                 Iskushuban         1604        16
#                 Qandala            1605        16
#                 Qardho             1606        16
# Bay             Baydhaba           2401        24
# ...

# %%
#cashforviz[['Region','District']].sort_values(by='Region')
s = cashforviz[cashforviz['Region']=='Awdal'][['Region','District']]
s.District.unique()
# Out:
# array(['Borama', 'Lughaye', 'Zeylac', 'Baki'], dtype=object)

# %%
pcoded = cashforviz.merge(pcodes, how='left', left_on='District',right_on='DIST_NAME')
pcoded.loc[pcoded['Region']=='Banadir', 'DIS_CODE']=22

# %%
pcoded.sort_values(by='Region')
# Out:
#             Cluster   Organization Conditionality   restriction  \
# 0        Protection  QATAR CHARITY  Unconditional  Unrestricted
# 1057  Food security            SCI  Cash for Work  Unrestricted
# 2204         WASH           UNICEF            NaN           NaN
# 367   Food security            FAO  Cash for Work  Unrestricted
# 366   Food security            FAO  Cash for Work  Unrestricted
# 365   Food security            FAO  Cash for Work  Unrestricted
# 364   Food security            FAO  Cash for Work  Unrestricted
# 363   Food security            FAO  Cash for Work  Unrestricted
# 1570  Food security            CWW  Unconditional  Unrestricted
# 1571  Food security            CWW  Unconditional  Unrestricted
# 1572  Food security            CWW  Unconditional  Unrestricted
# 296   Food security            FAO  Cash for Work  Unrestricted
# 295   Food security            FAO  Cash for Work  Unrestricted
# 294   Food security            FAO  Cash for Work  Unrestricted
# ...

# %%
pcoded['April Individuals'].isnull().sum()
pcoded['April Individuals'].fillna(0, inplace=True)

# %%
pcoded['Delivery mechanism'].fillna('Unspecified', inplace=True)
pcoded['Status (Completed, Ongoing, planned)'].fillna('Unspecified',inplace=True)
pcoded['restriction'].fillna('Unspecified', inplace=True)
pcoded['Conditionality'].fillna('Unspecified', inplace=True)

# %%
pcoded
# Out:
#             Cluster   Organization Conditionality   restriction  \
# 0        Protection  QATAR CHARITY  Unconditional  Unrestricted
# 1     Food security            DRC  Cash for Work  Unrestricted
# 2     Food security            ACF  Unconditional  Unrestricted
# 3     Food security            ACF  Unconditional  Unrestricted
# 4     Food security            ACF  Unconditional  Unrestricted
# 5     Food security         OTHERS  Unconditional  Unrestricted
# 6        Protection  QATAR CHARITY  Unconditional  Unrestricted
# 7     Food security            ACF  Unconditional  Unrestricted
# 8     Food security         OTHERS  Unconditional  Unrestricted
# 9     Food security            ACF  Unconditional  Unrestricted
# 10    Food security         OTHERS  Unconditional  Unrestricted
# 11    Food security            WVI  Cash for Work    Restricted
# 12    Food security            WVI  Unconditional  Unrestricted
# 13    Food security            ACF  Unconditional  Unrestricted
# ...

# %%
pcoded.to_csv('data/pcoded-cash.csv')
